# %% [markdown]
# Created by: Jennifer Bosch
#     9/23/16
#
# Plotting NDBC metrics of GTS messages
#
# Create a pie chart showing the % each IOOS asset contributes to the total # of GTS messages

# %%
#Importing packages
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
import numpy as np

# %matplotlib inline

# %%
#data file
filepath = 'C:\\Users\\jennifer.bosch\\Documents\\Metrics\\NDBC_GTS_metrics_2016.xlsx'

####Using Pandas to load data
df = pd.read_excel(filepath,0, index_col='Month')
df.dtypes
#xls_file = pd.ExcelFile(filepath)
# Out:
# IOOS Buoy          int64
# IOOS Ocean         int64
# IOOS Wave          int64
# IOOS UW Glider     int64
# IOOS Glider DAC    int64
# IOOS HF Radar      int64
# IOOS SAMS          int64
# IOOS CMAN          int64
# NDBC CMAN          int64
# NDBC Buoy          int64
# NDBC Ocean         int64
# NDBC Wave          int64
# TAO GTS            int64
# TAO BUFR           int64
# DART               int64
# dtype: object

# %%
#this data frame's index is "Month" in the spreadsheet.
df.index
# Out:
# Index([2015-10-01 00:00:00, 2015-11-01 00:00:00, 2015-12-01 00:00:00,
#        2016-01-01 00:00:00, 2016-02-01 00:00:00, 2016-03-01 00:00:00,
#        2016-04-01 00:00:00, 2016-05-01 00:00:00, 2016-06-01 00:00:00,
#        2016-07-01 00:00:00,       u'FY16 Total'],
#       dtype='object', name=u'Month')

# %%
#show the head lines of the data frame
df.head()
# Out:
#                      IOOS Buoy  IOOS Ocean  IOOS Wave  IOOS UW Glider  \
# Month
# 2015-10-01 00:00:00     291654      216243      86086             728
# 2015-11-01 00:00:00     209727      186188      83512             626
# 2015-12-01 00:00:00     178618      192760      77279               0
# 2016-01-01 00:00:00     170384      187895      80260               0
# 2016-02-01 00:00:00     174499      186456      84401               0
#
#                      IOOS Glider DAC  IOOS HF Radar  IOOS SAMS  IOOS CMAN  \
# Month
# 2015-10-01 00:00:00            17105          12497        657    2456318
# 2015-11-01 00:00:00             8733          12133        534    2178144
# 2015-12-01 00:00:00             1908          12519        200    2363684
# 2016-01-01 00:00:00             4937          12338        187    2487918
# 2016-02-01 00:00:00             4547          11733         76    2392408
#
#                      NDBC CMAN  NDBC Buoy  NDBC Ocean  NDBC Wave  TAO GTS  \
# ...

# %%
#the data frame has 11 rows and 15 columns
df.shape
# Out:
# (11, 15)

# %%
#List the totals for each type of message
df2a = df.loc['FY16 Total']
print(df2a)
# Out:
# IOOS Buoy           2251142
# IOOS Ocean          2025383
# IOOS Wave            872062
# IOOS UW Glider         8318
# IOOS Glider DAC       49744
# IOOS HF Radar        123023
# IOOS SAMS              3897
# IOOS CMAN          24248924
# NDBC CMAN            378878
# NDBC Buoy           1026922
# NDBC Ocean            29232
# NDBC Wave            717953
# TAO GTS              346260
# TAO BUFR             280269
# DART                 914472
# Name: FY16 Total, dtype: int64

# %%
#Calculate the IOOS asset percentage of the total gts messages

# %%
#Subsetting out the total counts from the table and 
#Transposting the row to a column for plotting
df2 = df.iloc[10:11,0:7].T

print(df2)
# Out:
# Month            FY16 Total
# IOOS Buoy           2251142
# IOOS Ocean          2025383
# IOOS Wave            872062
# IOOS UW Glider         8318
# IOOS Glider DAC       49744
# IOOS HF Radar        123023
# IOOS SAMS              3897

# %%
#plt.figure(figsize=(12,6))
df2.plot.pie(subplots=True,figsize=(10,10), autopct='%.1f', legend='best')
plt.title('IOOS Percent of total messages to the GTS')
#plt.legend(loc='best', frameon=False)
# Out:
# <img src="data:image/png;base64,...">
